# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Telco_customer_churn.xlsx")

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label Churn Value Churn Score  CLTV                   Churn Reason
# 0         Yes           1          86  3239   Competitor made better offer
# 1         Yes           1          67  2701                          Moved
# 2         Yes           1          86  5372                          Moved
# 3         Yes           1          84  5003                          Moved
# 4         Yes           1          89  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %%
df = df.drop(['CustomerID','Count','Country','State','City','Zip Code','Lat Long','Latitude','Longitude','Churn Reason','Churn Label','Churn Score','CLTV'],axis=1)

# %%
df.sample(5)
# Out:
#       Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 6228  Female             No      No         No              6           Yes
# 4242  Female             No     Yes        Yes             41            No
# 6401    Male             No      No         No              2           Yes
# 1582    Male            Yes     Yes         No              3           Yes
# 5193  Female             No     Yes         No             72           Yes
#
#         Multiple Lines Internet Service      Online Security  \
# 6228                No      Fiber optic                   No
# 4242  No phone service              DSL                  Yes
# 6401                No               No  No internet service
# 1582               Yes      Fiber optic                   No
# 5193               Yes               No  No internet service
#
#             Online Backup    Device Protection         Tech Support  \
# 6228                   No                  Yes                  Yes
# 4242                   No                  Yes                   No
# 6401  No internet service  No internet service  No internet service
# 1582                   No                   No                   No
# 5193  No internet service  No internet service  No internet service
#
#              Streaming TV     Streaming Movies        Contract  \
# 6228                   No                  Yes  Month-to-month
# 4242                   No                   No        One year
# 6401  No internet service  No internet service  Month-to-month
# 1582                  Yes                  Yes  Month-to-month
# 5193  No internet service  No internet service        Two year
#
#      Paperless Billing           Payment Method  Monthly Charges  \
# 6228               Yes         Electronic check            89.25
# 4242                No  Credit card (automatic)            35.40
# 6401               Yes         Electronic check            19.65
# 1582               Yes         Electronic check            94.60
# 5193               Yes             Mailed check            26.00
#
#      Total Charges  Churn Value
# 6228        487.05            0
# 4242        1412.4            0
# 6401          31.2            0
# 1582        279.55            1
# 5193          1776            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
#  16  Payment Method     7043 non-null   object
#  17  Monthly Charges    7043 non-null   float64
#  18  Total Charges      7043 non-null   object
#  19  Churn Value        7043 non-null   int64
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Tenure Months  Monthly Charges  Churn Value
# count    7043.000000      7043.000000  7043.000000
# mean       32.371149        64.761692     0.265370
# std        24.559481        30.090047     0.441561
# min         0.000000        18.250000     0.000000
# 25%         9.000000        35.500000     0.000000
# 50%        29.000000        70.350000     0.000000
# 75%        55.000000        89.850000     1.000000
# max        72.000000       118.750000     1.000000

# %%
df['Total Charges'] =pd.to_numeric(df['Total Charges'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
#  16  Payment Method     7043 non-null   object
#  17  Monthly Charges    7043 non-null   float64
#  18  Total Charges      7032 non-null   float64
#  19  Churn Value        7043 non-null   int64
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Tenure Months  Monthly Charges  Total Charges  Churn Value
# count    7043.000000      7043.000000    7032.000000  7043.000000
# mean       32.371149        64.761692    2283.300441     0.265370
# std        24.559481        30.090047    2266.771362     0.441561
# min         0.000000        18.250000      18.800000     0.000000
# 25%         9.000000        35.500000     401.450000     0.000000
# 50%        29.000000        70.350000    1397.475000     0.000000
# 75%        55.000000        89.850000    3794.737500     1.000000
# max        72.000000       118.750000    8684.800000     1.000000

# %%
df.isnull().sum()
# Out:
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Value           0
# dtype: int64

# %%
median_val = df['Total Charges'].median()
median_val
# Out:
# 1397.475

# %%
df['Total Charges'] = df['Total Charges'].fillna(median_val)

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure Months        0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn Value          0
# dtype: int64

# %%
x = df.drop('Churn Value',axis=1)
y = df['Churn Value']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

for col in x.columns:
    if x[col].dtype == 'object':
        x[col] = le.fit_transform(x[col])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
sns.countplot(x='Churn Value', data=df)
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn Value', data=df)
plt.show()

# %%
sns.boxplot(x='Churn Value', y='Tenure Months', data=df)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
print("accuracy:", accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy: 0.7856635911994322
# [[910  99]
#  [203 197]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1009
#            1       0.67      0.49      0.57       400
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.71      1409
# weighted avg       0.77      0.79      0.77      1409

# %%
importance = pd.Series(model.feature_importances_, index=x.columns)
importance.sort_values().plot(kind='barh',figsize=(10,6))
plt.title("Feature Importance")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

lr.fit(x_train, y_train)

y_pred_lr = lr.predict(x_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.8005677785663591

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(x_train, y_train)

y_pred_dt = dt.predict(x_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.7310149041873669

# %%
from sklearn.svm import SVC

svm = SVC()

svm.fit(x_train, y_train)

y_pred_svm = svm.predict(x_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.7927608232789212

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(x_train, y_train)

y_pred_knn = knn.predict(x_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.7629524485450674

# %%
import pickle

# %%
pickle.dump(lr,open("churn_model.pkl","wb"))
